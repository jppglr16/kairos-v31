# %% [markdown]
# # Kairos V31 Training on Google Colab
# Train all 18 instruments fast!

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Step 2: Install dependencies
# !pip install scikit-learn pandas numpy ta -q

# %%
# Step 3: Copy files from Drive
import shutil,os
# !cp -r '/content/drive/MyDrive/kairos_v31/' '/content/kairos/'
os.chdir('/content/kairos')
print('Files loaded!')

# %%
# Step 4: Run trainer
# !python3 v31_trainer.py

# %%
# Step 5: Run ensemble
# !python3 v31_ensemble.py

# %%
# Step 6: Save models to Drive
# !cp -r '/content/kairos/ml_models/' '/content/drive/MyDrive/kairos_v31_models/'
print('Models saved to Drive!')
